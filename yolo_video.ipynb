# %%
! pip install  opencv-contrib-python==3.4.2.17
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/IIT/Project/YOLO Object Detection with OpenCV
# Out:
# /content/drive/MyDrive/IIT/Project/YOLO Object Detection with OpenCV

# %%
! python yolo_video.py --input videos/drone.mp4 \
 --output output/drone.avi \
 --yolo yolo-coco
# Out:
# [INFO] loading YOLO from disk...
# [INFO] 599 total frames in video
# [INFO] single frame took 1.8856 seconds
# [INFO] estimated total time to finish: 1129.4755
# [INFO] cleaning up...
